# %%
import pandas as pd
import matplotlib.pyplot as plot

# %%
dataset = pd.read_csv("1976-2020-president.csv")
dataset
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 0     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# ...    ...      ...      ...         ...        ...       ...           ...
# 4282  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4283  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4284  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4285  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4286  2020  WYOMING       WY          56         83        68  US PRESIDENT
#
# ...

# %%
cleandf = dataset.groupby(["state",  "year", "party_simplified"]).agg({'candidatevotes':'max'})
cleandf

# %%
cleandf = cleandf.reset_index().groupby(["state", "year", "party_simplified"]).candidatevotes.agg("max").reset_index()
cleandf.party_simplified.agg("max")
# Out:
# 'REPUBLICAN'

# %%
cleandf.to_csv('clean_elections.csv', index=True)

# %%
data = pd.read_csv('clean_elections.csv')
data
# data.groupby(["state", "year"])['candidatevotes'].max()
# Out:
#         state  year party_simplified  candidatevotes
# 0     ALABAMA  1976         DEMOCRAT          659170
# 1     ALABAMA  1976      LIBERTARIAN            1481
# 2     ALABAMA  1976            OTHER            9198
# 3     ALABAMA  1976       REPUBLICAN          504070
# 4     ALABAMA  1980         DEMOCRAT          636730
# ...       ...   ...              ...             ...
# 2349  WYOMING  2016       REPUBLICAN          174419
# 2350  WYOMING  2020         DEMOCRAT           73491
# 2351  WYOMING  2020      LIBERTARIAN            5768
# 2352  WYOMING  2020            OTHER            2208
# 2353  WYOMING  2020       REPUBLICAN          193559
#
# [2354 rows x 4 columns]

# %%
votes_maxes = data.groupby(["state", "year"]).candidatevotes.transform(max)
cleandf =  data[data.candidatevotes == votes_maxes]
cleandf.rename(columns={"party_simplified":"party", "candidatevotes":"votes"}, inplace=True)
cleandf
# Out:
# C:\Users\javie\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#         state  year       party   votes
# 0     ALABAMA  1976    DEMOCRAT  659170
# 7     ALABAMA  1980  REPUBLICAN  654192
# 11    ALABAMA  1984  REPUBLICAN  872849
# 15    ALABAMA  1988  REPUBLICAN  815576
# 19    ALABAMA  1992  REPUBLICAN  804283
# ...       ...   ...         ...     ...
# 2337  WYOMING  2004  REPUBLICAN  167629
# 2341  WYOMING  2008  REPUBLICAN  164958
# 2345  WYOMING  2012  REPUBLICAN  170962
# 2349  WYOMING  2016  REPUBLICAN  174419
# 2353  WYOMING  2020  REPUBLICAN  193559
#
# [612 rows x 4 columns]

# %%
cleandf.to_csv("elecciones.csv", index=False)
